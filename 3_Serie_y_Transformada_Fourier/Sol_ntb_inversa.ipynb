# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianRodriguez05/SyS/blob/main/3_Serie_y_Transformada_Fourier/Sol_ntb_inversa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ejercicio
#
# * Obtener la transformada inversa de Laplace de
#     \begin{equation}
#     X(s) = \frac{1}{(s+1)(s+2)^2} \qquad \text{for } \Re \{ s \} \geq -1
#     \end{equation}
#     manualmente. Comprobar los resultados utilizando `SymPy`.

# %% [markdown]
# ![Imagen de WhatsApp 2025-03-01 a las 00.37.18_fb7eae69.jpg](data:image/jpeg;base64,...)

# %%
import sympy as sp

# Definir variables
s, t = sp.symbols('s t')

# Definir X(s)
X_s = 1 / ((s + 1) * (s + 2)**2)

# Transformada inversa de Laplace
x_t = sp.inverse_laplace_transform(X_s, s, t)
x_t
# Out:
# -t*exp(-2*t)*Heaviside(t) + exp(-t)*Heaviside(t) - exp(-2*t)*Heaviside(t)
