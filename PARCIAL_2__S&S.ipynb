# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianRodriguez05/SyS/blob/main/PARCIAL_2__S%26S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  #instalación de librerías
# !pip install streamlit -q
# !pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz #Pegar los links para el github
# Out:
# ...
#   Using cached https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz (2.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for yt-dlp: filename=yt_dlp-2025.1.26-py3-none-any.whl size=2930265 sha256=9a2fedc31e44d384ef0dde038700461da30cfe3b94c1c5516f4638ca604beb9f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ia_u9wmh/wheels/2d/79/97/7209650ef73114e0fe0603480da012ad3afacb9cae6b8acd9a
# Successfully built yt-dlp
# ...
#   Attempting uninstall: yt-dlp
#     Found existing installation: yt-dlp 2025.1.26
#     Uninstalling yt-dlp-2025.1.26:
#       Successfully uninstalled yt-dlp-2025.1.26
# ...

# %%
# !mkdir pages
# Out:
# mkdir: cannot create directory ‘pages’: File exists

# %% [markdown]
# # **Página principal**

# %%
# %%writefile 0_👋_BIENVENIDOS.py
import streamlit as st

st.set_page_config(
    page_title="PARCIAL DE SEÑALES Y SISTEMAS",
    page_icon="👋",
)

st.write("# Bienvenid@ a Señales y Sistemas! 👋") #TITULO PRINCIPAL


st.write("Integrantes: ")
st.write("Jhon Sebastian Rodriguez Lopez ")
st.write("Jeisson Andres Estrella Gonzalez")
st.write("Samuel Marulanda Salazar")
# Subtitulo
st.markdown("""
Este es el dashboard para la presentación del examen parcial 2 de *Señales y Sistemas*.
Aquí podrás explorar distintas secciones como el *Análisis de Señales, **Transformadas de Fourier* y más.
Selecciona una de las opciones del menú lateral para comenzar.
""")

#Barra lateral, indica elegir algun elemento del menu
st.sidebar.success("Seleccciona una demo a explorar.") #

#Links para más
st.markdown(
    """
    Streamlit te permitirá interactuar con los resultados de tu examen y visualizar los gráficos y análisis de señales en tiempo real.
    ¡Disfruta explorando!
    ### ¿Quieres saber más?
    - Consulta [streamlit.io](https://streamlit.io)
    - Revisa la [documentación de Streamlit](https://docs.streamlit.io)
"""
)
# Out:
# Overwriting 0_👋_BIENVENIDOS.py

# %% [markdown]
# # **Páginas**

# %%
# %%writefile 1_📈_EJERCICIO_1.py

import streamlit as st
import time
import numpy as np
import matplotlib.pyplot as plt

st.set_page_config(page_title="Plotting Demo", page_icon="📈")

# Parámetros iniciales
Fo = 60  # Frecuencia de la señal
T = 1 / Fo  # Periodo
Fs = 100 * Fo  # Frecuencia de muestreo definida
tv = np.arange(-T / 2, T / 2, 1 / Fs)  # Vector de tiempo generado
Nm = len(tv)  # Número de muestras requeridas
A = 1  # Amplitud de la señal
x1 = (A * np.cos(2 * np.pi * Fo * tv)) ** 2  # Señal cuadrática

# Número de armónicos
N = 50  # Cantidad de términos en la serie de Fourier
wo = 2 * np.pi / T  # Frecuencia fundamental

# Definir bases de Fourier
phin = np.zeros((Nm, 2 * N + 1), dtype=np.complex_)
for n in range(-N, N + 1, 1):
    phin[:, n + N] = np.exp(1j * n * wo * tv)  # Base de Fourier

# Calcular espectro
nv = np.linspace(-N, N, 2 * N + 1)  # Vector numérico de armónicos
Cn = np.zeros(2 * N + 1, dtype=np.complex_)
Cn[N] = (A ** 2) / 2  # Nivel DC
Cn[N + 2] = (A ** 2) / 4  # Primer armónico positivo
Cn[N - 2] = (A ** 2) / 4  # Primer armónico negativo

# Interfaz Streamlit
st.markdown("<h1 style='text-align: center;'>Análisis de Fourier de una Señal</h1>", unsafe_allow_html=True)

# Mostrar señal original
st.subheader("Señal Original")
st.write( "Esta gráfica muestra la señal original en el dominio del tiempo, una señal coseno elevada al cuadrado, que resulta en una forma de onda periódica con frecuencia 60 Hz."
)
fig, ax = plt.subplots()
ax.plot(tv, x1, 'r', linewidth=4)
ax.set_xlabel("t [s]")
ax.set_ylabel("x(t)")
ax.grid()
st.pyplot(fig)

# Graficar espectro
st.subheader("Espectro de Fourier")
st.write("El espectro de Fourier descompone la señal en sus componentes armónicas. Aquí se representan la parte real, imaginaria, magnitud y fase de los coeficientes de Fourier.")

fig, axs = plt.subplots(2, 2, figsize=(8, 8))
axs[0, 0].stem(nv, np.real(Cn), 'r')
axs[0, 0].set_title("Parte Real")
axs[0, 0].set_xlabel("n")
axs[0, 0].set_ylabel("Re{C_n}")
axs[0, 0].grid()

axs[0, 1].stem(nv, np.imag(Cn), 'r')
axs[0, 1].set_title("Parte Imaginaria")
axs[0, 1].set_xlabel("n")
axs[0, 1].set_ylabel("Im{C_n}")
axs[0, 1].grid()

axs[1, 0].stem(nv, abs(Cn), 'r')
axs[1, 0].set_title("Magnitud")
axs[1, 0].set_xlabel("n")
axs[1, 0].set_ylabel("|C_n|")
axs[1, 0].grid()

axs[1, 1].stem(nv, np.angle(Cn), 'r')
axs[1, 1].set_title("Fase")
axs[1, 1].set_xlabel("n")
axs[1, 1].set_ylabel("∠C_n")
axs[1, 1].grid()

fig.tight_layout()
st.pyplot(fig)

# Graficar espectro en dB y fase
st.subheader("Magnitud y Fase en dB")
st.write("Aquí se representa la magnitud en escala logarítmica (dB) y la fase en grados, mostrando la relevancia de cada armónico en la reconstrucción de la señal.")
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
axs[0].stem(nv, 20 * np.log10(abs(Cn)), 'r')
axs[0].set_title("Magnitud en dB")
axs[0].set_xlabel("n")
axs[0].set_ylabel("|C_n| [dB]")
axs[0].grid()

axs[1].stem(nv, np.angle(Cn, deg=True), 'r')
axs[1].set_title("Fase en Grados")
axs[1].set_xlabel("n")
axs[1].set_ylabel("Fase [°]")
axs[1].grid()

fig.tight_layout()
st.pyplot(fig)

# Interactivo: Señal reconstruida
st.subheader("Reconstrucción de la Señal")
st.write("Se reconstruye la señal usando una cantidad variable de armónicos. A medida que aumentamos los armónicos, la reconstrucción se acerca más a la señal original.")
Na = st.slider("Número de armónicos", 0, N, 1)
ind = np.arange(N - Na, N + Na + 1)
ind = np.clip(ind, 0, len(Cn) - 1)
Px = 0.375  # Estimar según señal estudiada
er = 1 - np.sum(abs(Cn[ind]) ** 2) / Px
xe = phin[:, ind] @ Cn[ind].ravel()

fig, ax = plt.subplots()
ax.plot(tv, xe, 'b', marker='o', markersize=5, label='$x_e(t)$')
ax.plot(tv, x1, 'r', label='x(t)')
ax.set_title(f'$E_r$={100 * er:.2f}%')
ax.set_xlabel("t [s]")
ax.set_ylabel("x(t)")
ax.grid()
ax.legend()
st.pyplot(fig)
# Out:
# Writing 1_📈_EJERCICIO_1.py

# %%
# !mv 1_📈_EJERCICIO_1.py pages/ #PARA QUE GUARDE LO NUEVO QUE HAGA

# %% [markdown]
# # **Página 2**

# %%
# %%writefile 2_🎵📊_EJERCICIO_2.py

import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
import yt_dlp
import soundfile as sf
from io import BytesIO
import tempfile
import os
from scipy.io.wavfile import write
import io

# Configuración inicial
st.title("Modulación AM")

# Parámetros
Fc = 100  # Frecuencia de la portadora (Hz)
Fm = 10   # Frecuencia del mensaje (Hz)
Am = 1    # Amplitud del mensaje

# Definición del tiempo
ti = 0
tf = 5 / Fm  # Número de períodos del mensaje a graficar
Fs = 5 * Fc  # Frecuencia de muestreo
t = np.arange(ti, tf, 1 / Fs)  # Vector de tiempo

# Generación de señales
m = Am * np.cos(2 * np.pi * Fm * t)  # Señal del mensaje
Im = 0.8  # Índice de modulación
Ac = max(abs(m)) / Im  # Amplitud de la portadora según el índice de modulación
c = Ac * np.sin(2 * np.pi * Fc * t)  # Señal portadora

y = (1 + m / Ac) * c  # Señal modulada en AM

# Gráfico 1: Señal de la portadora y mensaje
st.subheader("Señal de la portadora y mensaje")
fig1, ax1 = plt.subplots()
ax1.plot(t, c, label='Portadora')
ax1.plot(t, m, label='Mensaje')
ax1.set_xlabel("Tiempo (s)")
ax1.set_ylabel("Amplitud")
ax1.set_title("Portadora y mensaje en el tiempo")
ax1.legend()
st.pyplot(fig1)

# Explicación del gráfico 1
st.write("Este gráfico muestra la señal de la portadora (onda senoidal de alta frecuencia) y la señal del mensaje (onda cosenoidal de menor frecuencia). La portadora sirve como la base sobre la cual se modula la información del mensaje.")

# Gráfico 2: Señal modulada en AM
st.subheader("Señal modulada en AM")
fig2, ax2 = plt.subplots()
ax2.plot(t, y, label='Señal AM')
ax2.set_xlabel("Tiempo (s)")
ax2.set_ylabel("Amplitud")
ax2.set_title("Señal modulada en amplitud")
ax2.legend()
st.pyplot(fig2)

# Explicación del gráfico 2
st.write("En este gráfico se muestra la señal resultante después de la modulación en amplitud (AM). La envolvente de la señal modulada sigue la forma de la señal del mensaje, lo que permite recuperar la información original en el receptor.")

# Transformada de Fourier
Xfc = np.fft.fft(c)
Xfm = np.fft.fft(m)
Xfy = np.fft.fft(y)

vfre = np.fft.fftfreq(len(c), 1 / Fs)

# Gráfico 3: Espectro de frecuencia
st.subheader("Espectro de frecuencia de las señales")
fig3, ax3 = plt.subplots()
ax3.plot(vfre, abs(Xfy), label='Modulado')
ax3.plot(vfre, abs(Xfm), label='Mensaje')
ax3.plot(vfre, abs(Xfc), label='Portadora')
ax3.set_xlabel("Frecuencia (Hz)")
ax3.set_ylabel("|X(f)|")
ax3.set_title("Análisis espectral de las señales")
ax3.set_ylim([min(abs(Xfm)), 1.1 * max(abs(Xfm))])
ax3.legend()
st.pyplot(fig3)

# Explicación del gráfico 3
st.write("Este gráfico muestra el espectro de frecuencia de las señales. Se puede observar la señal del mensaje en bajas frecuencias, la portadora en su frecuencia correspondiente y la señal modulada con sus componentes espectrales en torno a la portadora.")

#Canción

# Configuración de la app
st.title("Descarga y reproducción de audio desde YouTube")

# Información de la canción
nombre_cancion = "BAD BUNNY - VOY A LLeVARTE PA PR (Visualizer) | DeBÍ TiRAR MáS FOToS"
st.write(f"**Canción:** {nombre_cancion}")

# Descarga del audio desde YouTube
def descargar_audio(url):
    ydl_opts = {
        'format': 'bestaudio/best',
        'extractaudio': True,
        'audioformat': 'mp3',
        'outtmpl': 'tema.mp3'
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

def convertir_a_wav():
    os.system("ffmpeg -y -i tema.mp3 output.wav")

# URL del video de YouTube
link = "https://www.youtube.com/watch?v=X2MGCIDOMZ4"
st.write("Descargando audio...")
descargar_audio(link)
st.write("Convirtiendo a WAV...")
convertir_a_wav()

# Cargar el audio
nombre_out = "output.wav"
x, fs = sf.read(nombre_out)

# Mostrar la frecuencia de muestreo
st.write(f"**Frecuencia de muestreo:** {fs} Hz")

# Selección del fragmento de audio (segundos 20 a 25)
inicio, fin = int(fs * 20), int(fs * 25)
segmento_audio = x[inicio:fin]

# Guardar el segmento en un archivo temporal
with tempfile.NamedTemporaryFile(delete=False, suffix=".wav") as temp_wav:
    sf.write(temp_wav.name, segmento_audio, fs)
    temp_wav_path = temp_wav.name

# Reproducir el audio en Streamlit
st.audio(temp_wav_path, format="audio/wav")

st.write("Este audio corresponde al segmento entre los segundos 20 y 25 de la canción.")

# Configuración de la app
st.title("Procesamiento de Audio y Modulación AM")

# Cargar el audio
nombre_out = "output.wav"
x, fs = sf.read(nombre_out)

# Seleccionar el canal izquierdo y fragmento de audio (segundos 20 a 25)
ti, tf = 20, 25
xpro = x.copy()
xs = xpro[int(ti * fs):int(tf * fs), 0]

# Vector de tiempo
tt = np.arange(ti, tf, 1 / fs)

# Gráfico 1: Señal original (canal izquierdo)
st.subheader("Señal Original del Canal Izquierdo")
fig1, ax1 = plt.subplots()
ax1.plot(tt, xs, label="Canal izquierdo")
ax1.set_xlabel("Tiempo (s)")
ax1.set_ylabel("Amplitud")
ax1.set_title("Señal de audio entre 20s y 25s")
ax1.legend()
st.pyplot(fig1)

# Explicación del gráfico 1
st.write("Este gráfico muestra la señal original del canal izquierdo en el intervalo de tiempo entre 20 y 25 segundos.")

# Entrada del usuario para el índice de modulación
Im = st.number_input("Ingrese el índice de modulación:", min_value=0.1, max_value=2.0, value=0.8, step=0.1)

# Parámetros de modulación AM
Fc = 1000  # Frecuencia de la portadora (Hz)
Fs = 48000  # Frecuencia de muestreo
t = np.arange(ti, tf, 1 / Fs)  # Vector de tiempo

# Generar la portadora
Ac = max(abs(xs)) / Im  # Amplitud de la portadora según índice de modulación
c = Ac * np.sin(2 * np.pi * Fc * t)  # Señal portadora

# Gráfico 2: Señal portadora y mensaje
st.subheader("Señal Portadora y Mensaje")
fig2, ax2 = plt.subplots()
ax2.plot(t, c, label='Portadora')
ax2.plot(t, xs, label='Mensaje')
ax2.set_xlabel("Tiempo (s)")
ax2.set_ylabel("Amplitud")
ax2.set_title("Comparación entre portadora y mensaje")
ax2.legend()
st.pyplot(fig2)

# Explicación del gráfico 2
st.write("En este gráfico se observa la señal portadora (onda senoidal de alta frecuencia) y la señal del mensaje original (audio extraído). La portadora se usa para modular la señal de audio.")

# Señal modulada en AM
y = (1 + xs / Ac) * c

# Gráfico 3: Señal modulada AM
st.subheader("Señal Modulada en AM")
fig3, ax3 = plt.subplots()
ax3.plot(t, y, label='Señal Modulada AM')
ax3.set_xlabel("Tiempo (s)")
ax3.set_ylabel("Amplitud")
ax3.set_title("Modulación AM de la Señal de Audio")
ax3.legend()
st.pyplot(fig3)

st.write("Este gráfico muestra la señal modulada en amplitud (AM). La forma de la señal refleja cómo la envolvente sigue la señal del mensaje, lo que permite transmitir la información del audio.")

# Transformada de Fourier
Xfc = np.fft.rfft(c)
Xfm = np.fft.rfft(xs)
Xfy = np.fft.rfft(y)
vfre = np.fft.rfftfreq(len(c), 1 / Fs)

# Gráfico 4: Espectro de la portadora
st.subheader("Espectro de Frecuencia de la Portadora")
fig4, ax4 = plt.subplots()
ax4.plot(vfre, abs(Xfc), label='Portadora')
ax4.set_xlabel("Frecuencia (Hz)")
ax4.set_ylabel("|X(f)|")
ax4.set_title("Espectro de Frecuencia de la Señal Portadora")
ax4.legend()
st.pyplot(fig4)
st.write("La señal portadora es una onda sinusoidal pura de frecuencia Fc = 1000 Hz. Su espectro de frecuencia muestra un único pico en esta frecuencia, ya que una onda sinusoidal tiene toda su energía concentrada en una sola frecuencia")

# Gráfico 5: Espectro de la Señal Modulada AM
st.subheader("Espectro de Frecuencia de la Señal Modulada")
fig5, (ax5a, ax5b) = plt.subplots(2, 1, figsize=(8, 8), constrained_layout=True)  # Aumentando el espacio
ax5a.plot(vfre, abs(Xfy), label='Modulado', color='r')
ax5a.set_xlabel("Frecuencia (Hz)")
ax5a.set_ylabel("|X(f)|")
ax5a.set_title("Espectro de la Señal Modulada AM")
ax5a.legend()
ax5a.set_ylim([min(abs(Xfm)), 1.1 * max(abs(Xfm))])

ax5b.plot(vfre, abs(Xfm), label='Mensaje')
ax5b.set_xlabel("Frecuencia (Hz)")
ax5b.set_ylabel("|X(f)|")
ax5b.set_title("Espectro de la Señal del Mensaje")
ax5b.legend()
ax5b.set_ylim([min(abs(Xfm)), 1.1 * max(abs(Xfm))])

st.pyplot(fig5)

st.write("El primer gráfico del espectro muestra la señal modulada en AM, donde se pueden ver las bandas laterales. El segundo gráfico muestra el espectro del mensaje original antes de la modulación.")

# Función para convertir el audio en un buffer
def convert_audio(data, rate):
    buffer = io.BytesIO()
    write(buffer, rate, data.astype(np.float32))
    buffer.seek(0)  # Reiniciar el puntero para asegurar la reproducción
    return buffer

# Convertir los audios antes de mostrarlos para reducir la demora
buffer_c = convert_audio(c, fs)
buffer_xs = convert_audio(xs, fs)
buffer_y = convert_audio(y, fs)

# Crear pestañas para seleccionar el audio
tab1, tab2, tab3 = st.tabs(["Portadora", "Mensaje", "Modulada"])

with tab1:
    st.subheader("Audio de la portadora")
    st.audio(buffer_c, format='audio/wav')

with tab2:
    st.subheader("Audio del mensaje original")
    st.audio(buffer_xs, format='audio/wav')

with tab3:
    st.subheader("Audio de la señal modulada")
    st.audio(buffer_y, format='audio/wav')

#PARTE ESCRITA

# URL de la carpeta de imágenes en Google Drive
drive_link = "https://drive.google.com/drive/u/0/folders/1OK3c9fOjyQxqKJdMXZKkVEqcJvQaQzVl"

# CSS para hacer el botón flotante
st.markdown(f"""
    <style>
    .floating-button {{
        position: fixed;
        bottom: 20px;
        right: 20px;
        background-color: #FF4B4B;
        color: white;
        padding: 10px 20px;
        border-radius: 25px;
        font-size: 18px;
        font-weight: bold;
        text-align: center;
        box-shadow: 2px 2px 10px rgba(0,0,0,0.3);
        cursor: pointer;
        transition: background-color 0.3s ease;
    }}
    .floating-button:hover {{
        background-color: #FF1F1F;
    }}
    </style>
    <a href="{drive_link}" target="_blank">
        <div class="floating-button">📸 Ver Parte escrita</div>
    </a>
""", unsafe_allow_html=True)
# Out:
# Writing 2_🎵📊_EJERCICIO_2.py

# %%
# !mv 2_🎵📊_EJERCICIO_2.py pages/ #PARA QUE GUARDE LO NUEVO QUE HAGA 3

# %%
# %%writefile 3_📈_EJERCICIO_3.py

import streamlit as st
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt


st.title("Análisis de la Distorsión Armónica Total (THD) y su Impacto en el Factor de Potencia")

st.markdown("La primera partede del ejercicio tres se en cuentra en el siguiente pdf: [Solucion teorica](https://drive.google.com/file/d/1LfKPqXS0-0PR8wcRxVwIi02X2JBbDUN1/view?usp=sharing)")


st.subheader("Carga Netamente Resistiva")

st.markdown("Para este caso, el circuito responde a:")


st.latex(r"V_R(s) = R I_{in}(s)")

st.latex(r"\frac{V_R(s)}{V_{in}(s)} = 1")


# Entrada de usuario para el valor de R
R_v = st.number_input("Ingrese el valor de R:", min_value=0.1, value=10.0)

# Parámetros de la simulación
Fo = 60  # Frecuencia de alimentación
Fs = 30 * Fo  # Frecuencia de muestreo
To = 1 / Fo  # Período fundamental
Ts = 1 / Fs  # Período de muestreo
t = np.arange(0, 5 * To, Ts)  # Simulación de 5 períodos

A = 120  # Amplitud de la entrada

# Función de entrada: onda senoidal rectificada completa
in_o = A * np.sin(2 * np.pi * Fo * t)
rec_c = sig.square(2 * np.pi * Fo * t)  # Tren de pulsos
in_ = in_o * rec_c  # Entrada rectificada completa

# Definir la función de transferencia
num = np.array([1])  # Coeficientes del numerador
den = np.array([1])  # Coeficientes del denominador
G_n = sig.TransferFunction(num, den)  # Sistema de primer orden

# Calcular la respuesta del sistema usando lsim
_, out, _ = sig.lsim(G_n, U=in_, T=t)

# --- Gráfica 1: Señal de alimentación ---

st.subheader("Señal de Alimentación")

st.markdown("Esta gráfica muestra la señal de alimentación antes de ser rectificada. Es una onda senoidal con una frecuencia de 60 Hz y una amplitud de 120V.")

fig, ax = plt.subplots()
ax.plot(t, in_o, label='Alimentación')
ax.legend()
st.pyplot(fig)

# --- Gráfica 2: Entrada rectificada ---

st.subheader("Señal de Entrada Rectificada")

st.markdown("Aquí se observa la señal de entrada después de ser rectificada. Se puede notar que la parte negativa de la onda senoidal ha sido eliminada, generando una forma de onda pulsante.")
fig, ax = plt.subplots()
ax.plot(t, in_, label='In(t)')
ax.set_xlabel('t [s]')
ax.set_ylabel('In(t)')
ax.legend()
st.pyplot(fig)

# --- Gráfica 3: Salida del circuito ---

st.subheader("Señal de Salida del Circuito")

st.markdown("La última gráfica muestra la salida del circuito resistivo. Como el sistema tiene una función de transferencia unitaria, la salida es similar a la entrada rectificada.")

fig, ax = plt.subplots()
ax.plot(t, out, c="r", label='Out(t)')
ax.set_xlabel('t [s]')
ax.set_ylabel('Out(t)')
ax.legend()
st.pyplot(fig)

st.markdown("Debido a que la resistencia es una carga no almacenadora de energía, el voltaje de entrada es igual al voltaje de salida")


st.subheader("Calculo del espectro")

vfre = np.fft.rfftfreq(len(out), 1 / Fs)  # Vector de frecuencia
Xf = np.fft.rfft(out)

# Visualización con Streamlit
st.title("Espectro de Frecuencia")

fig, ax = plt.subplots()
ax.stem(vfre, abs(Xf) / len(out))
ax.set_xlabel("Frecuencia [Hz]")
ax.set_ylabel("|X(f)|")
ax.set_title("Espectro de Frecuencia")
ax.grid()

st.pyplot(fig)

# Cálculo del THD
def calcular_thd(signal, Fs):
    Xf = np.fft.rfft(signal)  # FFT de la señal
    magnitudes = np.abs(Xf)
    freqs = np.fft.rfftfreq(len(signal), 1 / Fs)

    # Identificar la frecuencia fundamental
    fundamental_idx = np.argmax(magnitudes)
    fundamental = magnitudes[fundamental_idx]

    # Cálculo del THD como la suma de los armónicos sobre la fundamental
    thd = np.sqrt(np.sum(magnitudes[1:]**2)) / fundamental
    return thd

thd_r = calcular_thd(out, Fs)
st.write(f"**THD del circuito con carga resistiva:** {thd_r * 100:.2f}%")

pf=np.sqrt(1/(1+(thd_r)**2))
st.write(f"El factor de potencia de la señal con carga resistiva: {pf:.4f}")

R_v = st.number_input("Ingrese el valor de R:", min_value=0.0, value=1.0, step=0.1)
C_v = st.number_input("Ingrese el valor de C:", min_value=0.0, value=1.0e-6, step=1.0e-6)

# Definir valores de tiempo y señal de entrada (deben estar definidos antes de usarlos)
Fs = 1000  # Frecuencia de muestreo
t = np.linspace(0, 0.1, int(0.1 * Fs), endpoint=False)  # Vector de tiempo
in_ = np.abs(np.sin(2 * np.pi * 50 * t))  # Señal de entrada rectificada

# Función de transferencia del circuito RC
if R_v > 0 and C_v > 0:  # Evita valores inválidos
    num = np.array([1])
    den = np.array([R_v * C_v, 1])
    G_n = sig.TransferFunction(num, den)

    # Evaluar salida ante entrada rectificada mediante respuesta al sistema
    tout, out, _ = sig.lsim(G_n, in_, T=t)

    # Gráfico de la señal de entrada y salida
    fig, ax = plt.subplots()
    ax.plot(t, in_, label='In(t)')  # Entrada rectificada
    ax.plot(t, out, label='Out(t)')  # Salida del circuito
    ax.set_xlabel('t [s]')
    ax.set_ylabel('out(t)')
    ax.legend()
    st.pyplot(fig)

    # Calcular la FFT
    vfre = np.fft.rfftfreq(len(out), 1 / Fs)  # Vector de frecuencia en Hz
    Xf = np.fft.rfft(out)

    # Crear la gráfica del espectro de frecuencia
    fig, ax = plt.subplots()
    ax.stem(vfre, abs(Xf) / len(out), basefmt=" ")  # Evitar línea base en la gráfica
    ax.set_xlabel('Frecuencia [Hz]')
    ax.set_ylabel('|X(f)|')
    ax.set_title('Espectro de Frecuencia')
    ax.grid()
    st.pyplot(fig)

    # Función para calcular el THD
    def calcular_thd(signal, Fs):
        Xf = np.fft.rfft(signal)  # FFT de la señal
        magnitudes = np.abs(Xf)

        if len(magnitudes) < 2:  # Evita errores si la FFT es demasiado pequeña
            return 0

        # Identificar la frecuencia fundamental
        fundamental_idx = np.argmax(magnitudes)
        fundamental = magnitudes[fundamental_idx]

        if fundamental == 0:  # Evita divisiones por cero
            return 0

        # Cálculo del THD como la suma de los armónicos sobre la fundamental
        thd = np.sqrt(np.sum(magnitudes[1:] ** 2)) / fundamental
        return thd

    # Cálculo del THD para el circuito RC (con filtro)
    thd_rc = calcular_thd(out, Fs)
    st.write(f"THD del circuito RC: {thd_rc * 100:.2f}%")

    # Cálculo del factor de potencia
    pf = np.sqrt(1 / (1 + (thd_rc) ** 2))
    st.write(f"El factor de potencia de la señal con carga RC: {pf:.4f}")

else:
    st.error("Los valores de R y C deben ser mayores que cero.")
# Out:
# Writing 3_📈_EJERCICIO_3.py

# %%
# !mv 3_📈_EJERCICIO_3.py pages/

# %%
# %%writefile 4_📈_EJERCICIO_4.py

import streamlit as st
import os
import zipfile
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from scipy.spatial.distance import cdist
from io import BytesIO


# 1. Subir el archivo ZIP mediante Streamlit
uploaded_file = st.file_uploader("Sube un archivo ZIP", type="zip")

if uploaded_file is not None:
    # 2. Crear carpeta destino
    output_dir = "results"
    os.makedirs(output_dir, exist_ok=True)

    # 3. Guardar el archivo ZIP en la carpeta de destino
    zip_path = os.path.join(output_dir, uploaded_file.name)
    with open(zip_path, "wb") as f:
        f.write(uploaded_file.getbuffer())

    # 4. Extraer el contenido en la carpeta 'results/'
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(output_dir)

    st.write(f"Archivos extraídos en '{output_dir}/'")

    # Mostrar los archivos extraídos
    extracted_files = os.listdir(output_dir)
    st.write("Archivos extraídos:")
    st.write(extracted_files)



# Definir la ruta base donde están las carpetas de los audios
base_path = "results/audios/"

# Verificar si la ruta existe
if os.path.exists(base_path):
    # Lista para almacenar los datos
    data = []

    # Recorrer las carpetas dentro de 'results/audios/'
    for folder in os.listdir(base_path):
        folder_path = os.path.join(base_path, folder)

        # Verificar que sea una carpeta
        if os.path.isdir(folder_path):
            # Recorrer los archivos dentro de la carpeta
            for file in os.listdir(folder_path):
                if file.endswith(".wav"):  # Solo considerar archivos WAV
                    # Definir la clave
                    clave = 1 if folder == "Samuel" else 2

                    # Agregar los datos a la lista
                    data.append([file, folder, clave])

    # Crear un DataFrame con los datos
    df = pd.DataFrame(data, columns=["NOMBRE DEL ARCHIVO", "ESTUDIANTE", "CLAVE"])

    # Mostrar el DataFrame en Streamlit
    st.write("### Tabla de archivos de audio")
    st.dataframe(df)
else:
    st.error(f"La carpeta '{base_path}' no existe. Asegúrate de extraer los archivos ZIP primero.")




# Selecciona un archivo específico (puedes cambiar estos valores)
nombre_audio = "segment_10.wav"  # Cambia esto por el archivo que quieres reproducir
carpeta_audio = "Samuel"  # Cambia esto por la carpeta donde está el audio

# Ruta completa del audio
audio_path = os.path.join("results/audios", carpeta_audio, nombre_audio)

# Verificar si el archivo existe antes de cargarlo
if os.path.exists(audio_path):
    # Cargar el audio
    y, sr = librosa.load(audio_path, sr=None)  # Carga el audio con la frecuencia original

    # Reproducir el audio en Streamlit
    st.write(f"### Reproduciendo: {nombre_audio}")
    st.audio(audio_path, format="audio/wav")

    # Mostrar la forma de onda (waveform)
    fig, ax = plt.subplots(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr, ax=ax)
    ax.set_title(f"Forma de onda de {nombre_audio}")
    ax.set_xlabel("Tiempo (s)")
    ax.set_ylabel("Amplitud")

    # Mostrar la gráfica en Streamlit
    st.pyplot(fig)

    # Mostrar la forma del array de audio y la frecuencia de muestreo
    st.write(f"**Shape del audio:** {y.shape}")
    st.write(f"**Frecuencia de muestreo:** {sr} Hz")
else:
    st.error(f"El archivo '{nombre_audio}' no se encuentra en la carpeta '{carpeta_audio}'.")


st.write("### Dimensiones del DataFrame")
st.write(f"**Filas:** {df.shape[0]}")
st.write(f"**Columnas:** {df.shape[1]}")

#__________________________________________________________________________

# Ruta donde están las carpetas de audios
base_path = "results/audios/"

# Lista para almacenar duraciones
duraciones = []

# Recorrer todas las carpetas en 'results/audios/' (Samuel y Sebastian)
for folder in ["Samuel", "Sebastian"]:  # Aseguramos que recorra ambas carpetas
    folder_path = os.path.join(base_path, folder)

    if os.path.isdir(folder_path):  # Verificar si la carpeta existe
        for file in os.listdir(folder_path):
            if file.endswith(".wav"):
                audio_path = os.path.join(folder_path, file)
                y, sr = librosa.load(audio_path, sr=None)
                duracion = librosa.get_duration(y=y, sr=sr)
                duraciones.append(duracion)

# Calcular la duración media
if duraciones:
    duracion_media = np.mean(duraciones)
    st.write(f"### Duración media de los audios: {duracion_media:.2f} segundos")
else:
    st.error("No se encontraron archivos de audio en las carpetas especificadas.")

# Crear carpeta para audios recortados
output_folder = "results/audios_recortados"
os.makedirs(output_folder, exist_ok=True)

# Lista para guardar los archivos recortados
audios_recortados = []

# Recorrer de nuevo ambas carpetas y recortar los audios
for folder in ["Samuel", "Sebastian"]:
    folder_path = os.path.join(base_path, folder)

    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            if file.endswith(".wav"):
                audio_path = os.path.join(folder_path, file)
                y, sr = librosa.load(audio_path, sr=None)

                # Duración en muestras de la media
                muestras_recorte = int(duracion_media * sr)

                # Recortar si es más largo
                if len(y) > muestras_recorte:
                    y = y[:muestras_recorte]

                # Guardar el audio recortado en una subcarpeta por estudiante
                output_subfolder = os.path.join(output_folder, folder)
                os.makedirs(output_subfolder, exist_ok=True)  # Crear subcarpeta si no existe

                output_path = os.path.join(output_subfolder, file)
                sf.write(output_path, y, sr)
                audios_recortados.append(output_path)

st.write("### Recorte de audios completado")
st.write(f"Archivos guardados en `{output_folder}`")

# Escuchar los audios recortados en Streamlit
if audios_recortados:
    st.write("### Audios recortados")
    for audio_path in audios_recortados:
        st.write(f"🔊 **{os.path.basename(audio_path)}**")
        st.audio(audio_path, format="audio/wav")
else:
    st.error("No se generaron archivos recortados.")

#_______________________________________________________________________

# Ruta donde están los audios recortados
base_path = "results/audios_recortados/"

# Definir estudiantes y sus etiquetas
estudiantes = {"Samuel": 1, "Sebastian": 2}

# Lista de archivos y etiquetas
wav_files = []
labels = []

# Recorrer las carpetas y almacenar los archivos
for folder, label in estudiantes.items():
    folder_path = os.path.join(base_path, folder)
    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            if file.endswith(".wav"):
                wav_files.append(os.path.join(folder_path, file))
                labels.append(label)

# Validar si hay archivos de audio
if not wav_files:
    st.error("No se encontraron archivos de audio en las carpetas especificadas.")
else:
    # Parámetros de segmentación
    ts = 1  # Duración de los audios en segundos
    fs = 48000  # Frecuencia de muestreo
    Ns = len(wav_files)  # Cantidad total de segmentos

    # Inicializar matriz de audio y etiquetas
    x_t = np.zeros((Ns, int(fs)))  # Matriz de audio (mono)
    label_array = np.zeros((Ns, 1))  # Vector de etiquetas
    name_c = []

    # Mostrar barra de progreso en Streamlit
    progress_bar = st.progress(0)

    for i, file_path in enumerate(wav_files):
        x, fs = sf.read(file_path)
        x = x[:, 0] if x.ndim > 1 else x  # Convertir a mono si es estéreo

        if len(x) > fs:
            x_t[i] = x[:fs]
        else:
            x_t[i, : len(x)] = x

        label_array[i] = labels[i]
        name_c.append(os.path.basename(file_path))

        # Actualizar barra de progreso
        progress_bar.progress((i + 1) / Ns)

    st.success("Vector de audios y etiquetas creado correctamente.")

    # Mostrar detalles en Streamlit
    st.write(f"### Total de audios procesados: {Ns}")
    st.write("**Ejemplo de archivos procesados:**")
    st.write(name_c[:5])  # Mostrar los primeros 5 nombres de archivos

#________________________________________________________________________

i = 10

# Verificar que el índice esté dentro del rango
if i < len(x_t):
    st.write(f"🔊 **Reproduciendo el audio del segmento {i}**")
    st.audio(x_t[i], format="audio/wav", sample_rate=fs)
else:
    st.error("El índice del segmento seleccionado está fuera del rango.")

vf = np.fft.rfftfreq(x_t.shape[1], 1/fs)  # Vector de frecuencias
Xw = np.fft.rfft(x_t, axis=1)  # FFT de la señal a lo largo del tiempo

st.write("### 🔬 Transformada de Fourier Calculada")
st.write(f"**Dimensiones de la FFT:** {Xw.shape}")


# Obtener la magnitud del espectro
Xw_mag = np.abs(Xw)

# Encontrar el índice de la frecuencia máxima por cada audio
idx_max_freq = np.argmax(Xw_mag, axis=1)

# Convertir índices a frecuencias
f_max = vf[idx_max_freq]

# Mostrar las frecuencias máximas para cada audio
st.write("Frecuencia máxima por audio:", max(f_max))

# Crear la figura para Streamlit
fig, ax = plt.subplots(figsize=(10, 4))

for i in range(Ns):
    ax.plot(np.linspace(0, ts, x_t.shape[1]), x_t[i], alpha=0.5)  # Agregar transparencia

ax.set_xlabel("t [s]")
ax.set_ylabel("Amplitud")
ax.set_title("Forma de onda de todos los audios")

# Mostrar la gráfica en Streamlit
st.pyplot(fig)

#________________________________________________________________________

st.write("### 📊 Espectro de Frecuencia")

# Crear la figura para Streamlit
fig, ax = plt.subplots()

ax.plot(vf, abs(Xw).T)
ax.set_xlabel('Frecuencia [Hz]')
ax.set_ylabel('|X(f)|')
ax.set_title('Espectro de Frecuencia')

# Mostrar la gráfica en Streamlit
st.pyplot(fig)

#_________________________________________________________________________


# Normalización del espectro
sca = MinMaxScaler()
Xw_ = sca.fit_transform(abs(Xw).T).T

# Gráfica: Espectro de Frecuencia Normalizado
st.write("### 📊 Espectro de Frecuencia Normalizado")
fig, ax = plt.subplots()
ax.plot(vf, Xw_.T)
ax.set_xlabel('Frecuencia [Hz]')
ax.set_ylabel('|X(f)|')
st.pyplot(fig)

# Gráfica: Espectro de Frecuencia en dB
st.write("### 🔊 Espectro de Frecuencia en dB")
fig, ax = plt.subplots()
ax.plot(vf, (20 * np.log10(Xw_ + 1e-10)).T)  # Evitar discontinuidad del log
ax.set_xlabel('Frecuencia [Hz]')
ax.set_ylabel('|X(f)| dB')
st.pyplot(fig)

#__________________________________________________________________________


# Selección del método de reducción de dimensionalidad en Streamlit
method = st.selectbox("Selecciona el método", ["TSNE", "PCA"])

if method == "TSNE":
    red_ = TSNE(perplexity=20, n_components=2, random_state=123, learning_rate='auto', init='pca')
else:
    red_ = PCA(n_components=2, random_state=123)

fmax = 1603
X_2D = red_.fit_transform(Xw_[:, :fmax])  # Se tiene en cuenta el espectro hasta fmax Hz
label = label_array.flatten()


# Graficar separabilidad 2D
st.subheader("Separabilidad en 2D")
fig, ax = plt.subplots()
scatter = ax.scatter(X_2D[:, 0], X_2D[:, 1], c=label, s=1)
plt.colorbar(scatter, ax=ax)

color_ = ["b", "y"]  # Azul para Samuel, Amarillo para Sebastian

for i, tex in enumerate(name_c):
    nombre = tex[:-4]  # Quita la extensión ".wav"
    estudiante = "Samuel" if label[i] == 1 else "Sebastian"  # Asigna el nombre correcto
    ax.text(X_2D[i, 0] * 1.025, X_2D[i, 1] * 1.025, f"{estudiante}_{nombre}",
            fontsize=6, color=color_[int(label[i] - 1)])

# Mostrar la figura en Streamlit
st.pyplot(fig)

num_puntos = X_2D.shape[0]
st.write(f"Total de puntos en la gráfica: {num_puntos}")

#------------------------------------------------------------------


st.title("Procesamiento de Audio con Streamlit")

# 1. Subir el archivo de audio
uploaded_file = st.file_uploader("Sube un archivo de audio", type=["wav", "mp3", "ogg"])

if uploaded_file is not None:
    # 2. Cargar el audio
    y, sr = librosa.load(uploaded_file, sr=None)

    # 3. Reproducir el audio
    st.audio(uploaded_file, format='audio/wav')

    # 4. Mostrar la forma de onda
    fig, ax = plt.subplots(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr, ax=ax)
    ax.set_title("Forma de onda del audio")
    ax.set_xlabel("Tiempo (s)")
    ax.set_ylabel("Amplitud")
    st.pyplot(fig)

    # 5. Mostrar el array de audio (shape)
    st.write(f"Shape del audio: {y.shape}")
    st.write(f"Frecuencia de muestreo: {sr} Hz")

#------------------------------------------------------------------------

# Cargar el archivo de audio
sr = 22050  # Frecuencia de muestreo (ejemplo)
y = np.random.randn(sr * 2)  # Simulación de audio de 2 segundos

duracion_deseada = 1.0  # 1 segundo
muestras_deseadas = int(duracion_deseada * sr)

if len(y) > muestras_deseadas:
    y = y[:muestras_deseadas]  # Recortar
elif len(y) < muestras_deseadas:
    y = np.pad(y, (0, muestras_deseadas - len(y)))  # Rellenar con ceros

# Graficar en Streamlit
fig, ax = plt.subplots(figsize=(10, 4))
librosa.display.waveshow(y, sr=sr, ax=ax)
ax.set_title("Forma de onda recortada a 1 segundo")
ax.set_xlabel("Tiempo (s)")
ax.set_ylabel("Amplitud")
st.pyplot(fig)

# Mostrar la nueva longitud del audio recortado
st.write(f"Shape del audio recortado: {y.shape}")

#------------------------------------------------------------------



# Simulación de datos
sr = 22050  # Frecuencia de muestreo (ejemplo)
y = np.random.randn(sr * 2)  # Simulación de audio de 2 segundos
Xw_ = np.random.randn(10, 24001)  # Espectros de Fourier antiguos
Xw_nuevo_normalizado = np.random.randn(300)  # Nuevo espectro
label_array_flat = np.random.randint(0, 2, size=(10,))  # Etiquetas antiguas
nuevo_audio = "nuevo_audio.wav"

# Determinar el número máximo de puntos en el espectro
max_len = Xw_.shape[1]
fmax = Xw_nuevo_normalizado.shape[0]

# Ajustar la longitud del espectro del nuevo audio
Xw_nuevo_normalizado_resized = np.pad(Xw_nuevo_normalizado[:fmax], (0, max_len - Xw_nuevo_normalizado[:fmax].shape[0]), mode='constant')

# Concatenar espectros de Fourier
X_combined = np.concatenate([Xw_, Xw_nuevo_normalizado_resized.reshape(1, -1)], axis=0)

# Concatenar etiquetas
target_label = 2  # Suponiendo que el nuevo audio es de "Sebastian"
label_combined = np.concatenate([label_array_flat, np.array([target_label])])

# Reducción de dimensión con PCA
red_ = PCA(n_components=2, random_state=123)
X_2D_combined = red_.fit_transform(X_combined)

# Graficar en Streamlit
fig, ax = plt.subplots(figsize=(8, 6))
scatter = ax.scatter(X_2D_combined[:-1, 0], X_2D_combined[:-1, 1], c=label_combined[:-1], s=20, cmap='coolwarm', label='Audios antiguos')
ax.scatter(X_2D_combined[-1, 0], X_2D_combined[-1, 1], c='g', s=50, label='Nuevo audio')
ax.text(X_2D_combined[-1, 0] * 1.03, X_2D_combined[-1, 1] * 1.03, f"{nuevo_audio}", fontsize=7, color='g', ha='left', va='top')
fig.colorbar(scatter, label='Etiqueta')
ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')
ax.set_title('Separabilidad 2D de los espectros de Fourier')
ax.legend()
st.pyplot(fig)

#----------------------------------------------------------------------


# Título de la aplicación
st.title("Visualización de Separabilidad 2D de los Espectros de Fourier")

# Cargar los datos necesarios (simulación de datos)
Xw_ = np.random.rand(10, 24001)  # Datos antiguos simulados
label_array_flat = np.random.randint(0, 2, size=(10,))  # Etiquetas simuladas
Xw_nuevo_normalizado = np.random.rand(24001)  # Nuevo espectro simulado
nuevo_audio = "audio_nuevo.wav"

# Determinar el número máximo de puntos en el espectro
max_len = Xw_.shape[1]

# Ajustar la longitud del espectro del nuevo audio
Xw_nuevo_normalizado_resized = np.pad(
    Xw_nuevo_normalizado[:max_len],
    (0, max_len - Xw_nuevo_normalizado[:max_len].shape[0]),
    mode='constant'
)

# Concatenar todos los espectros
X_combined = np.concatenate([Xw_, Xw_nuevo_normalizado_resized.reshape(1, -1)], axis=0)

# Concatenar etiquetas
label_combined = np.concatenate([label_array_flat, np.array([2])])  # Etiqueta 2 para "Sebastian"

# Usar PCA para reducir la dimensión
red_ = PCA(n_components=2, random_state=123)
X_2D_combined = red_.fit_transform(X_combined)

# Crear la figura
fig, ax = plt.subplots(figsize=(8, 6))
sc = ax.scatter(
    X_2D_combined[:-1, 0], X_2D_combined[:-1, 1],
    c=label_combined[:-1], s=20, cmap='coolwarm', label='Audios antiguos'
)
ax.scatter(X_2D_combined[-1, 0], X_2D_combined[-1, 1], c='g', s=50, label='Nuevo audio')
ax.text(X_2D_combined[-1, 0] * 1.03, X_2D_combined[-1, 1] * 1.03, f"{nuevo_audio}",
        fontsize=7, color='g', ha='left', va='top')
ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')
ax.set_title('Separabilidad 2D de los espectros de Fourier')
ax.legend()
fig.colorbar(sc, label='Etiqueta')

# Mostrar en Streamlit
st.pyplot(fig)


#------------------------------------------------------------------------

# Simulación de datos de entrada (esto debe ser reemplazado por los datos reales)
X_2D_combined = np.random.rand(10, 2)  # 10 puntos en 2D
label_combined = np.random.choice([0, 1], size=10)  # Etiquetas aleatorias 0 o 1

# Extraer las representaciones 2D de los audios antiguos
X_old = X_2D_combined[:-1]  # Todos los puntos menos el último
labels_old = label_combined[:-1]  # Etiquetas de los audios antiguos

# Obtener las coordenadas 2D del nuevo audio
X_new = X_2D_combined[-1].reshape(1, -1)  # El nuevo audio es el último punto

# Calcular las distancias entre el nuevo audio y todos los anteriores
distances = cdist(X_new, X_old, metric='euclidean')  # Usamos la distancia euclidiana

# Encontrar el índice de la distancia mínima
index_closer = np.argmin(distances)  # Índice del audio más cercano

# Obtener la etiqueta del audio más cercano
closest_label = labels_old[index_closer]

# Definir un umbral de distancia para aceptación
umbral_distancia = 0.35  # Ajusta este valor según tus necesidades

# Verificar si el nuevo audio está más cerca del grupo con etiqueta 1 y si la distancia es menor que el umbral
aceptado = closest_label == 1 and distances[0, index_closer] < umbral_distancia

# Interfaz en Streamlit
st.title("Verificación de Audio por Distancia Euclidiana")

st.write("Coordenadas del nuevo audio:", X_new[0])
st.write("Coordenadas del audio más cercano:", X_old[index_closer])
st.write(f"Distancia mínima: {distances[0, index_closer]:.4f}")
st.write(f"Etiqueta del audio más cercano: {closest_label}")

if aceptado:
    st.success("✅ Audio ACEPTADO")
else:
    st.error("❌ Audio RECHAZADO")
# Out:
# Writing 4_📈_EJERCICIO_4.py

# %%
# !mv 4_📈_EJERCICIO_4.py pages/

# %% [markdown]
# # **Inicialización del Dashboard**

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !mv cloudflared-linux-amd64 /usr/local/bin/cloudflared

#Ejecutar Streamlit
# !streamlit run 0_👋_BIENVENIDOS.py &>/content/logs.txt & #Cambiar 0_👋_Hello.py por el nombre de tu archivo principal

#Exponer el puerto 8501 con Cloudflare Tunnel
# !cloudflared tunnel --url http://localhost:8501 > /content/cloudflared.log 2>&1 &

#Leer la URL pública generada por Cloudflare
import time
time.sleep(5)  # Esperar que se genere la URL

import re
found_context = False  # Indicador para saber si estamos en la sección correcta

with open('/content/cloudflared.log') as f:
    for line in f:
        #Detecta el inicio del contexto que nos interesa
        if "Your quick Tunnel has been created" in line:
            found_context = True

        #Busca una URL si ya se encontró el contexto relevante
        if found_context:
            match = re.search(r'https?://\S+', line)
            if match:
                url = match.group(0)  #Extrae la URL encontrada
                print(f'Tu aplicación está disponible en: {url}')
                break  #Termina el bucle después de encontrar la URL
# Out:
# --2025-02-11 03:32:35--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.2.0/cloudflared-linux-amd64 [following]
# --2025-02-11 03:32:35--  https://github.com/cloudflare/cloudflared/releases/download/2025.2.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...
